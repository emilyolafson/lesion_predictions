# %%
# Import the required libraries
import nibabel as nib

# Set the path to the GIFTI image
gii_image = '/Users/emilyolafson/GIT/ENIGMA/testfig/HCP_S1200_GroupAvg_v1/subcortical_volumes.nii.gzR.shape.gii'

# Load the GIFTI image
gii_data = nib.load(gii_image)

# Update the colormap metadata of the GIFTI image
keys = gii_data.meta.metadata
print(keys)



# Save the updated GIFTI image
nib.save(gii_data, '/Users/emilyolafson/GIT/ENIGMA/testfig/updated_image.gii')
# Out:
# {'AnatomicalStructurePrimary': 'CortexRight', 'ParentProvenance': '/home/ubuntu/enigma/motor_predictions/wb_files/HCP_S1200_GroupAvg_v1/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii:\n/nrgpackages/tools.release/workbench-rh_linux64-v1.2.0/bin_rh_linux64/../exe_rh_linux64/wb_command -surface-average /home/shared/HCP/taskfmri/phase2/fmri/HCP_1200/S1200/S1200/MNINonLinear/fsaverage_LR32k/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii -uncertainty /home/shared/HCP/taskfmri/phase2/fmri/HCP_1200/S1200/S1200/MNINonLinear/fsaverage_LR32k/S1200.R.midthickness_MSMAll_uncertainty.32k_fs_LR.shape.gii -stddev /home/shared/HCP/taskfmri/phase2/fmri/HCP_1200/S1200/S1200/MNINonLinear/fsaverage_LR32k/S1200.R.midthickness_MSMAll_std.32k_fs_LR.shape.gii -surf /home/shared/HCP/taskfmri/phase2/fmri/HCP_1200/S1200/100206/MNINonLinear/fsaverage_LR32k/100206.R.midthickness_MSMAll.32k_fs_LR.surf.gii -surf /home/shared/HCP/taskfmri/phase2/fmri/HCP_1200/S1200/100307/MNINonLinear/fsaverage_LR32k/100307.R.midthi
# ...

# %%
type(gii_data.meta)
# Out:
# nibabel.gifti.gifti.GiftiMetaData
