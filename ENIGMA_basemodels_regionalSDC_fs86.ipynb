# %%
import sys; sys.path
import pandas as pd
import numpy as np 
import seaborn as sns
import scipy.io as sio
import os
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold, StratifiedKFold
from sklearn import preprocessing, linear_model
from sklearn.metrics import explained_variance_score, r2_score, make_scorer
from sklearn.preprocessing import StandardScaler
from joblib import parallel_backend, Parallel, delayed


import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
data_dir = '/home/ubuntu/enigma/'
results_dir='/home/ubuntu/enigma/results/correlation_regionalSDC_fs86/'


df =  pd.read_csv(data_dir + 'Behaviour_Information_ALL_April7_2022.csv', header=0)
idx=np.isnan(df['NORMED_MOTOR'])

df=df[~idx]

site=df['SITE']

chronicity=df['CHRONICITY']
df_chronic=df[df['CHRONICITY']==180]
df_chronic=df_chronic.reset_index(drop=True)
ids=df_chronic['BIDS_ID']
ses=df_chronic['SES']
ids.to_csv(data_dir + '/chronic_ids.csv')

# Load SC regional (chronic)

# sub-r029s005 no MRI?
# sub-r052s034 no MRI?

nROIs=86
sc= np.zeros([len(ids),86])

# unpickle 
import pickle
import numpy as np
import scipy.io as sio
import os
import glob

nROIs=86
sc= np.zeros([len(ids),86])

# sub-r029s005 no MRI?
# sub-r052s034 no MRI?

#chacovol
for i in range(0,len(ids)):
    if i==293:
        continue
    if i==519:
        continue
    with open('/home/ubuntu/enigma/fs86/%s_ses-1_space-MNI152_desc-T1-lesion_mask_MNI_1mm_nemo_output_sdstream_chacovol_fs86subj_mean.pkl' % (ids[i]), 'rb') as e:
        data = pickle.load(e)
        sio.savemat('/home/ubuntu/enigma/fs86/%s_ses-1_space-MNI152_desc-T1-lesion_mask_MNI_1mm_nemo_output_sdstream_chacovol_fs86subj_mean.mat'% (ids[i]), {'chacovol':data})
        sc[i,:] = data
    
    
sc = np.delete(sc,(293), axis=0)   
sc = np.delete(sc,(519), axis=0)   

fuglmeyer=df_chronic['NORMED_MOTOR']

fuglmeyer.pop(293)
fuglmeyer.pop(519)
# Out:
# 0.378787879

# %%
def feature_select_correlation(x_train, x_test, y, a):
    """Return values for the top a features of x based on abs. value Spearman correlation with y.
         Inputs:
             x_train = input matrix for training subjects
             x_test = input matrix for test subjects
             y = variable/s predicted 
             a = number of features to retain
        
        Returns:
            x_train_featselect = training data with selected features 
            x_test_featselect = test data matrix with selected features
            ind = indices of top a features """
    
    # check that dimension of x is greater than a
    if x_train.shape[1]<a:
        raise Exception('Number of features in X is less than the number of features specified to retain (a).') 
        
        
    # Feature selection: use only the top n features based on correlation of training features with y
    correl = abs(np_pearson_cor(x_train, y))
    ind = np.argpartition(correl, -a, 0)[-a:] # select top a features

    # return training/test data with only top features
    x_train_featselect=np.squeeze(x_train[:,ind],2)
    
    x_test_featselect=np.squeeze(x_test[:,ind],2)

    return x_train_featselect,x_test_featselect, ind


def gcv_ridge(hyperparam, x, y, k, featsel='None', a=10):
    """Perform gridsearch using k-fold cross-validation on a single hyperparameter 
    in ridge regression, and return mean R^2 across inner folds.
    
    Inputs: 
        hyperparam = list of hyperparameter values to train & test on validation est
        x = N x p input matrix
        y = 1 x p variable to predict
        k = k value in k-fold cross validation 
        featsel = type string, feature selection method, default="None"
            'None' - no feature selection; use all variables for prediction
            'correlation'- calculate the abs. val. Pearson correlation between all training variables with the varibale to predict. Use the highest 'a' variables based on their correlation for prediction
            'PCA' - perform PCA on the training variables and use the top 'a' PCs as input variables, by variance explained, for prediction
        a = number of features to select using one of the above methods, default=10 
    
    Returns:
        expl_var = the mean R^2 (coefficient of determination) across inner loop folds for the given hyperparameter
    """
    
    # make sure k is reasonable 
    if x.shape[0]/k <= 2:
        raise Exception('R^2 is not well-defined with less than 2 subjects.')   
    
    # set alpha in ridge regression
    alpha = hyperparam
    # Initialize lists with final results
    y_pred_total = []
    y_valid_total = []
    R2 = []
    comp = []
    correl=[]
    explvar=[]
    # Split data into test and train: random state fixed for reproducibility
    kf = KFold(n_splits=k,shuffle=True,random_state=43)
    
    # K-fold cross-validation 
    for train_index, valid_index in kf.split(x):
        x_train, x_valid = x[train_index], x[valid_index]
        y_train, y_valid = y[train_index], y[valid_index]
        
        #x_train, x_valid = scale_data(x_train, x_valid)
        
        if featsel=='correlation':
            x_train, x_valid, ind = feature_select_correlation(x_train, x_valid, y_train, a)
            comp.append(ind)
            
        elif featsel=='PCA':
            x_train, x_valid, components = feature_select_PCA(x_train, x_valid, a)
            comp.append(components)
        
        # Fit ridge regression with (x_train_scaled, y_train), and predict x_train_scaled
        regr = linear_model.Ridge(alpha=alpha, normalize=True, max_iter=1000000, random_state=42)
        y_pred = regr.fit(x_train, y_train).predict(x_valid)

        R2.append(r2_score(y_valid, y_pred))
        correlation=np_pearson_cor(y_pred, y_valid)[0]
        correl.append(correlation)
        explvar.append(explained_variance_score(y_valid, y_pred))
        
        # Append y_pred and y_valid values of this k-fold step to list with all values
        y_pred_total.append(y_pred)
        y_valid_total.append(y_valid)
 
    # note: don't use r2_score for ridge regression bc it does not account for bias error
    r2=np.mean(R2)
    
    cor=np.mean(correl)
    
    # use explained_variance_score instead:
    expl_var=np.mean(explvar)
    
    return expl_var


def parallel_featsearch(alpha, X, Y, k, featselect, feat):
    ''' Grid search in parallel.

    Returns:
        expl_var - explained variance for given combination of alpha/feat/featselect'''
    
    expl_var=gcv_ridge(alpha, X, Y, k, featselect, feat)
    return expl_var


# Inner loop - grid search
def gridsearch_cv(k, x, y, featselect, alphas, feats):
    ''' Performs grid search using fixed predefined hyperparameter ranges and returns the best alpha and # of features for 
        a given training/validation sample. 
        
        Input:
            x = N x p input matrix
            y = 1 x p variable to predict
            k = k value in k-fold cross validation 
            featsel = type string, feature selection method, default="None"
                'None' - no feature selection; use all variables for prediction
                'correlation'- calculate the abs. val. Pearson correlation between all training variables with the varibale to predict. Use the highest 'a' variables based on their correlation for prediction
                'PCA' - perform PCA on the training variables and use the top 'a' PCs as input variables, by variance explained, for prediction
            alphas - range of alpha parameters to search 
            feats - range of # features to search
        
        Returns:
            bestalpha - optimal alpha based on grid search
            bestfeats - optimal number of features based on grid search
            bestr2 - mean R^2 across folds obtained for the optimal combination of hyperparameters
            gcv_values - R^2 across all combinations of hyperparametrs.'''
    
    print(str(k)+"-fold cross-validation results in "+str((x.shape[0]/k)*(k-1))+ " subjects in the training set, and "+ str(x.shape[0]/k) + " subjects in the validation set")

    # initialize array to store r2
    gcv_values=np.empty(shape=(len(alphas),len(feats)),dtype='float')

    # iterate through alphas
    for alpha in alphas:
        row, = np.where(alphas==alpha)
        
        # run feature selection (# of components) in parallel
        gcv=Parallel(n_jobs=-1,verbose=0)(delayed(parallel_featsearch)(alpha,x, y, k, featselect, feat) for feat in feats)
        gcv=np.array(gcv)
        gcv_values[row]=gcv
            
        row=np.argmax(np.max(gcv_values, axis=1))
        col=np.argmax(np.max(gcv_values, axis=0))

    bestalpha=alphas[row]
    bestfeats=feats[col]
    bestr2=np.max(gcv_values)

    return bestalpha, bestfeats, bestr2, gcv_values


def np_pearson_cor(x, y):
    '''Fast array-based pearson correlation that is more efficient. 
    FROM: https://cancerdatascience.org/blog/posts/pearson-correlation/.
        x - input N x p
        y - output N x 1
        
        returns correlation p x 1 '''
    xv = x - x.mean(axis=0)
    yv = y - y.mean(axis=0)
    xvss = (xv * xv).sum(axis=0)
    yvss = (yv * yv).sum(axis=0)
    result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
    
    # bound the values to -1 to 1 in the event of precision issues
    return np.maximum(np.minimum(result, 1.0), -1.0)

# %%
# -------------------- MODEL OPTIMIZATION --------------------
# range of alphas
n_alphas=30
alpha_start=-2
alpha_end=2
alphas = np.logspace(alpha_start, alpha_end, n_alphas, base=10,dtype=None)
p=0

#number of features (# pricipal components or variables to retain)
feat_start=10
feat_end=86

n_feats=feat_end-feat_start+1
feats = np.linspace(feat_start, feat_end, n_feats, dtype=int)

#set the proportion of data you want in your training set
train_size = .8

#set the number of folds you want in the inner and outer folds of the nested cross-validation
k = 5
#set x data to be the input variable you want to use
#ie fc, sc, or hc
#X=np.concatenate([sc, fc], axis=1)
X=np.array(sc)

#set y to be the measure you want to predict
Y = np.array(fuglmeyer)
Y=np.reshape(Y, (627,1))

featselect = 'correlation'

# set aside data for hold-out final testing: 
x, x_test, y, y_test = train_test_split(X, Y, test_size=1-train_size, shuffle=True, random_state=134)

bestalpha, bestfeats, bestr2, gcv_values_r2= gridsearch_cv(k, x, y, featselect, alphas, feats)

row=np.argmax(np.max(gcv_values_r2, axis=1))
col=np.argmax(np.max(gcv_values_r2, axis=0))
k = 5
bestalpha=alphas[row]
bestfeats=feats[col]

print('Best combination: \n alpha = ', str(alphas[row]), '\n Features = ', str(feats[col]), '\n R^2 = ', str(np.round(np.max(gcv_values_r2), 3)))

# initialize Ridge regression with alpha selected from hyperparameter search
regr = linear_model.Ridge(alpha=bestalpha, normalize=True, max_iter=1000000, random_state=p)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1-train_size, shuffle=True, random_state=121)

if featselect=='correlation':
    x_train_featselect,x_test_featureselect,ind = feature_select_correlation(x_train,x_test, y_train, bestfeats)

# initialize Ridge regression with alpha selected from hyperparameter search
regr = linear_model.Ridge(alpha=bestalpha, normalize=True, max_iter=1000000, random_state=p)


# fit model 
y_pred = regr.fit(x_train_featselect, y_train).predict(x_test_featureselect)

expl=explained_variance_score(y_test, y_pred)

print(expl)

plt.scatter(y_test, y_pred)
# Out:
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# Best combination:
#  alpha =  2.212216291070448
#  Features =  75
#  R^2 =  0.148
# 0.10736047134388793

# %%
plot_figure(gcv_values_r2,'correlation_regionalSDC_fs86',0.96)
# Out:
# <ipython-input-9-f8c56cbeb99d>:20: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()

# %%
def plot_figure(gcv_values, string, midpoint):
    '''Plots the R^2 value obtained across all grid-search pairs (# features and regularization values.)
    
    Inputs:
        gcv_values - matrix to plot
        string - title
        midpoint - point at which blue turns to red.'''
    
    plt.figure(figsize=(17,14))
    shifted_cmap = shiftedColorMap(plt.get_cmap('bwr'), midpoint=midpoint, name='shifted')

    plt.imshow(gcv_values, cmap=shifted_cmap, interpolation='nearest')

    plt.xlabel('# Features', fontsize=15, fontweight='bold')
    plt.ylabel('Alphas', fontsize=15, fontweight='bold')

    row=np.argmax(np.max(gcv_values, axis=0))
    col=np.argmax(np.max(gcv_values, axis=1))

    ax = plt.axes()

    ax.xaxis.set_major_locator(plt.MultipleLocator(1))
    ax.yaxis.set_major_locator(plt.MultipleLocator(1))

    xticks= np.linspace(feat_start, feat_end,n_feats, dtype=int)
    yticks= np.logspace(alpha_start, alpha_end, n_alphas, base=10, dtype=None)

    plt.xticks(np.arange(len(feats)), fontsize=18)
    plt.yticks(np.arange(len(alphas)), fontsize=18)

    ax.set_xticklabels(xticks)
    ax.set_yticklabels(np.round(yticks,3))

    #ax.xaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{xticks: .2f}'))
    cbar = plt.colorbar()
    cbar.set_label('R^2')
    plt.title(string + '_Best R^2 = ' + str(np.round(np.max(gcv_values), 3)), fontsize=20)

    plt.scatter(row,col,color='k')
    #plt.savefig(results_dir+string+ '.png')
    plt.show()
    
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import AxesGrid

def shiftedColorMap(cmap, start=0, midpoint=0.5, stop=1.0, name='shiftedcmap'):
    '''
    FROM: https://stackoverflow.com/questions/7404116/defining-the-midpoint-of-a-colormap-in-matplotlib
    Function to offset the "center" of a colormap. Useful for
    data with a negative min and positive max and you want the
    middle of the colormap's dynamic range to be at zero.

    Input
    -----
      cmap : The matplotlib colormap to be altered
      start : Offset from lowest point in the colormap's range.
          Defaults to 0.0 (no lower offset). Should be between
          0.0 and `midpoint`.
      midpoint : The new center of the colormap. Defaults to 
          0.5 (no shift). Should be between 0.0 and 1.0. In
          general, this should be  1 - vmax / (vmax + abs(vmin))
          For example if your data range from -15.0 to +5.0 and
          you want the center of the colormap at 0.0, `midpoint`
          should be set to  1 - 5/(5 + 15)) or 0.75
      stop : Offset from highest point in the colormap's range.
          Defaults to 1.0 (no upper offset). Should be between
          `midpoint` and 1.0.
    '''
    cdict = {
        'red': [],
        'green': [],
        'blue': [],
        'alpha': []
    }

    # regular index to compute the colors
    reg_index = np.linspace(start, stop, 257)

    # shifted index to match the data
    shift_index = np.hstack([
        np.linspace(0.0, midpoint, 128, endpoint=False), 
        np.linspace(midpoint, 1.0, 129, endpoint=True)
    ])

    for ri, si in zip(reg_index, shift_index):
        r, g, b, a = cmap(ri)

        cdict['red'].append((si, r, r))
        cdict['green'].append((si, g, g))
        cdict['blue'].append((si, b, b))
        cdict['alpha'].append((si, a, a))

    newcmap = matplotlib.colors.LinearSegmentedColormap(name, cdict)
    plt.register_cmap(cmap=newcmap)

    return newcmap

# %%
# predictions for SC-  PCA and correlation

import datetime
import pickle 

# feature selection type
f=['correlation']

for featselect in f: 
    #set the number of folds you want in the inner and outer folds of the nested cross-validation
    k = 5

    #set the proportion of data you want in your training set
    train_size = .8

    #X=np.concatenate([sc, fc], axis=1)
    X=sc

    #set y to be the measure you want to predict
    #Y = np.log(np.array(tmt))

    Y=np.array(fuglmeyer)
    Y=np.reshape(Y, (627,1))
    
    # range of alphas
    n_alphas=30
    alpha_start=-2
    alpha_end=2
    alphas = np.logspace(alpha_start, alpha_end, n_alphas, base=10, dtype=None)

    #number of features (# pricipal components or variables to retain)
    feat_start=10
    feat_end=86
    n_feats=feat_end-feat_start+1
    feats = np.linspace(feat_start, feat_end, n_feats, dtype=int)

    # initialize lists to store model results for each permuation
    allR2=[]
    meanR2=[]
    features=[]
    bestalphas=[]
    importance=[]
    allexpl_var=[]
    correlations=[]
    chronic_allexpl_var=[]
    chronic_correlationr2_all=[]
    #joblib-based parallelism to increase speed,
    ytestc=[]
    ypredc=[]
    for p in range(0, 100):
        outer_cv = KFold(n_splits=k, shuffle=True, random_state=p)
        print('Permutation: ' + str(p))
        # initialize lists to store model results for eah fold
        R2=[]
        featur=[]
        best_alphas=[]
        impt=[] 
        expl_var=[]
        chronic_explvar=[]
        chronic_correlationr2=[]

        cor=[]
        for train, test in outer_cv.split(X):
            begin_time = datetime.datetime.now()
            
            
            # select model using training data
            bestalpha, bestfeats, bestr2, gcv_values = gridsearch_cv(k, X[train], Y[train], featselect, alphas, feats)

            # using optimal num. of features, select final features using entire training data.

            if featselect=='correlation':
                x_train_featselect,x_test_featureselect,ind = feature_select_correlation(X[train],X[test], Y[train], bestfeats)
                featur.append(ind)

            elif featselect=='PCA':
                x_train_featselect,x_test_featureselect,ind  = feature_select_PCA(X[train],X[test], bestfeats)
                featur.append(ind)
                
            # initialize Ridge regression with alpha selected from hyperparameter search
            regr = linear_model.Ridge(alpha=bestalpha, normalize=True, max_iter=1000000, random_state=p)

            # fit model 
            y_pred = regr.fit(x_train_featselect, Y[train]).predict(x_test_featureselect)

            # store results for each fold k
            impt.append(regr.coef_)
            expl_var.append(explained_variance_score(Y[test], y_pred))

            best_alphas.append(bestalpha)
            print('time to run loop: ' + str(datetime.datetime.now() - begin_time)) 
            print("Explained var: " + str(explained_variance_score(Y[test], y_pred)))
            print("correlation: " + str(np_pearson_cor(Y[test], y_pred)))
            
    
            cor.append(np_pearson_cor(Y[test], y_pred))
            Xtest=x_test_featureselect
            Xtrain=X[train]
            Ytest=Y[test]

        # store results for each permutation p

        allexpl_var.append(expl_var)
        bestalphas.append(best_alphas)
        importance.append(impt)
    
        print("---- Permutation avg. explained variance: " + str(np.mean(expl_var)) + "----")
        np.savetxt(results_dir + featselect + 'p' + str(p) + '_SC_all_explvar.txt', expl_var, delimiter=',')

        output = open(results_dir + featselect + 'p' + str(p) + '_SC_features.pkl', 'wb')
        pickle.dump(featur, output)
        output.close()
        
        output = open(results_dir + featselect + 'p' + str(p) + '_SC_correlations.pkl', 'wb')
        pickle.dump(correlations, output)
        output.close()

        output = open(results_dir + featselect + 'p' + str(p) + '_SC_bestalphas.pkl', 'wb')
        pickle.dump(best_alphas, output)
        output.close()
     
        output = open(results_dir + featselect + 'p' + str(p) + '_SC_varimpt.pkl', 'wb')
        pickle.dump(impt, output)
        output.close()
# Out:
# Permutation: 0
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:06.090931
# Explained var: 0.16461720557782267
# correlation: [[0.41058347]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:04.968670
# Explained var: 0.20475615173166384
# correlation: [[0.45681818]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:05.156510
# Explained var: 0.13290397390405395
# correlation: [[0.36866889]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:06.589295
# Explained var: 0.21456228197007665
# correlation: [[0.46875588]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.333178
# Explained var: 0.13917488841121473
# correlation: [[0.37309004]]
# ---- Permutation avg. explained variance: 0.17120290031896637----
# Permutation: 1
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.297485
# Explained var: 0.16650990965494694
# correlation: [[0.41220242]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.942060
# Explained var: 0.1943583479427211
# correlation: [[0.44795803]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.565318
# Explained var: 0.20026426007358955
# correlation: [[0.44762274]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.473577
# Explained var: 0.19395177178736778
# correlation: [[0.44217236]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.539259
# Explained var: 0.1134302568563681
# correlation: [[0.35158228]]
# ---- Permutation avg. explained variance: 0.1737029092629987----
# Permutation: 2
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.750665
# Explained var: 0.21645597519315396
# correlation: [[0.4776365]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.477571
# Explained var: 0.2403270311112513
# correlation: [[0.49059182]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.441357
# Explained var: -0.004703592305474347
# correlation: [[0.19741049]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.568186
# Explained var: 0.11431909517304784
# correlation: [[0.36772183]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.379103
# Explained var: 0.12937873067802474
# correlation: [[0.36679189]]
# ---- Permutation avg. explained variance: 0.1391554479700007----
# Permutation: 3
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.748376
# Explained var: 0.22579215009312292
# correlation: [[0.48106091]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.640661
# Explained var: 0.21378638154731977
# correlation: [[0.47674492]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.275024
# Explained var: 0.1808680150729648
# correlation: [[0.42657114]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.488065
# Explained var: 0.12793770711612384
# correlation: [[0.38115363]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.428953
# Explained var: 0.15371479317740733
# correlation: [[0.39241974]]
# ---- Permutation avg. explained variance: 0.18041980940138774----
# Permutation: 4
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.502287
# Explained var: 0.202739349073369
# correlation: [[0.45619873]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.283158
# Explained var: 0.12182305137892513
# correlation: [[0.38126787]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.624353
# Explained var: 0.1526230047863406
# correlation: [[0.39084186]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.321818
# Explained var: 0.24810854202192456
# correlation: [[0.50402881]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.592585
# Explained var: 0.17984038885654097
# correlation: [[0.42432539]]
# ---- Permutation avg. explained variance: 0.18102686722342004----
# Permutation: 5
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.677624
# Explained var: 0.1550599921560899
# correlation: [[0.39405313]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.776853
# Explained var: 0.24172426485615484
# correlation: [[0.49896769]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.368496
# Explained var: 0.19281644522391794
# correlation: [[0.44284782]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.466533
# Explained var: 0.23804943535282286
# correlation: [[0.49122122]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.436411
# Explained var: 0.043731591402904835
# correlation: [[0.27848421]]
# ---- Permutation avg. explained variance: 0.17427634579837809----
# Permutation: 6
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.603199
# Explained var: 0.1156775357973141
# correlation: [[0.35367691]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.266887
# Explained var: 0.23610947188695852
# correlation: [[0.49457388]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.698441
# Explained var: 0.23804559396008707
# correlation: [[0.49301345]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.463067
# Explained var: 0.09627629684943306
# correlation: [[0.33102028]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.541653
# Explained var: 0.20044714396282592
# correlation: [[0.45922247]]
# ---- Permutation avg. explained variance: 0.17731120849132373----
# Permutation: 7
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.508837
# Explained var: 0.06611404548084643
# correlation: [[0.32325984]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.612201
# Explained var: 0.18917896295190295
# correlation: [[0.45518342]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.740145
# Explained var: 0.15298452837516718
# correlation: [[0.39113702]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.359997
# Explained var: 0.14851841165864654
# correlation: [[0.39425368]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.742843
# Explained var: 0.2460765925797237
# correlation: [[0.50328851]]
# ---- Permutation avg. explained variance: 0.16057450820925737----
# Permutation: 8
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.483712
# Explained var: 0.1374647952190977
# correlation: [[0.37570743]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.680446
# Explained var: 0.17842937193757802
# correlation: [[0.4365467]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.840830
# Explained var: 0.1583047515277226
# correlation: [[0.40007377]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:10.000056
# Explained var: 0.2559452929820477
# correlation: [[0.50978313]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.631823
# Explained var: 0.1556845190416979
# correlation: [[0.39662918]]
# ---- Permutation avg. explained variance: 0.17716574614162878----
# Permutation: 9
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.696252
# Explained var: 0.18751493690125565
# correlation: [[0.43526978]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.814602
# Explained var: 0.13250128562882957
# correlation: [[0.36406099]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.522248
# Explained var: 0.2551782001135148
# correlation: [[0.50673255]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.528320
# Explained var: 0.2517578957116279
# correlation: [[0.50734179]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.522415
# Explained var: 0.12479187785843548
# correlation: [[0.3571948]]
# ---- Permutation avg. explained variance: 0.19034883924273266----
# Permutation: 10
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.236178
# Explained var: 0.16270713343684606
# correlation: [[0.4063035]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.319693
# Explained var: 0.12196435407288275
# correlation: [[0.35352186]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.567133
# Explained var: 0.10567905336562278
# correlation: [[0.3360591]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.494567
# Explained var: 0.22054058250813668
# correlation: [[0.47020369]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.486045
# Explained var: 0.2385573780130218
# correlation: [[0.49412922]]
# ---- Permutation avg. explained variance: 0.169889700279302----
# Permutation: 11
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.922600
# Explained var: 0.057437692235884796
# correlation: [[0.31268461]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.663953
# Explained var: 0.22602061159304643
# correlation: [[0.47625408]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.443262
# Explained var: 0.16908652478420572
# correlation: [[0.41148867]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.350477
# Explained var: 0.16620597927650327
# correlation: [[0.40773166]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.565797
# Explained var: 0.2180986465418755
# correlation: [[0.46739676]]
# ---- Permutation avg. explained variance: 0.16736989088630314----
# Permutation: 12
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.248522
# Explained var: 0.18783704527757106
# correlation: [[0.43582215]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.425407
# Explained var: 0.15499466885249769
# correlation: [[0.39371327]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.500539
# Explained var: 0.21814442991388927
# correlation: [[0.46737673]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.321710
# Explained var: 0.18516376680151403
# correlation: [[0.43032409]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.773468
# Explained var: 0.10450049773013081
# correlation: [[0.33223835]]
# ---- Permutation avg. explained variance: 0.17012808171512056----
# Permutation: 13
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.444326
# Explained var: 0.15227809064363151
# correlation: [[0.39037996]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.707589
# Explained var: 0.20511740249511712
# correlation: [[0.45399946]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.470532
# Explained var: 0.2006896894716499
# correlation: [[0.45031186]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.373396
# Explained var: 0.16892033595263878
# correlation: [[0.41104782]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.946535
# Explained var: 0.14680732611829128
# correlation: [[0.40131823]]
# ---- Permutation avg. explained variance: 0.1747625689362657----
# Permutation: 14
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.435831
# Explained var: 0.1912407149746993
# correlation: [[0.43764919]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.461948
# Explained var: 0.15966222358391402
# correlation: [[0.40002051]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.076005
# Explained var: 0.19072782393423726
# correlation: [[0.43763879]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.583357
# Explained var: 0.19245333756114147
# correlation: [[0.43870063]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.362414
# Explained var: 0.18641048529069537
# correlation: [[0.43249076]]
# ---- Permutation avg. explained variance: 0.1840989170689375----
# Permutation: 15
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.729349
# Explained var: 0.28796960780781256
# correlation: [[0.55879829]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.635010
# Explained var: 0.06452602079915581
# correlation: [[0.27971959]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.417617
# Explained var: 0.15817053899332478
# correlation: [[0.39903061]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.706829
# Explained var: 0.18528949330870603
# correlation: [[0.43068049]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.471040
# Explained var: 0.18773061346610287
# correlation: [[0.43341487]]
# ---- Permutation avg. explained variance: 0.1767372548750204----
# Permutation: 16
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.701435
# Explained var: 0.19063140037714632
# correlation: [[0.4398239]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.359706
# Explained var: 0.18019941482418544
# correlation: [[0.42663099]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:10.125924
# Explained var: 0.1957150658984107
# correlation: [[0.45229692]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.445960
# Explained var: 0.12194129510326246
# correlation: [[0.37257542]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.611056
# Explained var: 0.16269740138488586
# correlation: [[0.40521248]]
# ---- Permutation avg. explained variance: 0.17023691551757816----
# Permutation: 17
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.593069
# Explained var: 0.31194305572627234
# correlation: [[0.62138152]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.833926
# Explained var: 0.07088719690551804
# correlation: [[0.3346537]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.406528
# Explained var: 0.1368188091256094
# correlation: [[0.37010849]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.476225
# Explained var: 0.17902064990390532
# correlation: [[0.4232963]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.418801
# Explained var: 0.1214602623443235
# correlation: [[0.36569551]]
# ---- Permutation avg. explained variance: 0.16402599480112573----
# Permutation: 18
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.449558
# Explained var: 0.21835003049477364
# correlation: [[0.46759353]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.824029
# Explained var: 0.16821903233104873
# correlation: [[0.4104628]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.419647
# Explained var: 0.22277627826617696
# correlation: [[0.47602697]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.749781
# Explained var: 0.15907183361866128
# correlation: [[0.39922293]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.466800
# Explained var: 0.13327505352769653
# correlation: [[0.38146573]]
# ---- Permutation avg. explained variance: 0.18033844564767143----
# Permutation: 19
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.536993
# Explained var: 0.17374164683105098
# correlation: [[0.41773075]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.851956
# Explained var: 0.20460612453818783
# correlation: [[0.46256014]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.368874
# Explained var: 0.1831314587068087
# correlation: [[0.43067728]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.912178
# Explained var: 0.12706949888400787
# correlation: [[0.36192133]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.478972
# Explained var: 0.19933919884146778
# correlation: [[0.44693937]]
# ---- Permutation avg. explained variance: 0.17757758556030462----
# Permutation: 20
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.700130
# Explained var: 0.19983810427116977
# correlation: [[0.45216534]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.479718
# Explained var: 0.1761643806060208
# correlation: [[0.4259135]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.618548
# Explained var: 0.105595988890552
# correlation: [[0.33436504]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.436204
# Explained var: 0.25706688793438326
# correlation: [[0.51190314]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.761016
# Explained var: 0.16566779864577008
# correlation: [[0.40706619]]
# ---- Permutation avg. explained variance: 0.18086663206957918----
# Permutation: 21
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.604969
# Explained var: 0.18618900700177976
# correlation: [[0.43180134]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.645365
# Explained var: 0.17127867798670116
# correlation: [[0.41392629]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.987984
# Explained var: 0.24032696937762066
# correlation: [[0.49103536]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.379007
# Explained var: 0.19890731506144577
# correlation: [[0.44656898]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.378639
# Explained var: 0.012089405245245932
# correlation: [[0.22635706]]
# ---- Permutation avg. explained variance: 0.16175827493455866----
# Permutation: 22
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.490487
# Explained var: 0.18712154609320708
# correlation: [[0.43257969]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.350541
# Explained var: 0.2013452744279185
# correlation: [[0.45001899]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.376138
# Explained var: 0.1374723274077646
# correlation: [[0.37152843]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.458227
# Explained var: 0.20530832176291558
# correlation: [[0.45337106]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.633770
# Explained var: 0.18122180863440063
# correlation: [[0.42593675]]
# ---- Permutation avg. explained variance: 0.1824938556652413----
# Permutation: 23
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.393276
# Explained var: 0.14530021929969583
# correlation: [[0.38796837]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.959718
# Explained var: 0.1788559379959339
# correlation: [[0.42312432]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.619299
# Explained var: 0.05355189341525746
# correlation: [[0.30214289]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.624874
# Explained var: 0.22413152952651527
# correlation: [[0.48520168]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.623029
# Explained var: 0.22377500019064955
# correlation: [[0.47491153]]
# ---- Permutation avg. explained variance: 0.16512291608561042----
# Permutation: 24
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.816637
# Explained var: 0.1789421027545206
# correlation: [[0.42364174]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.663572
# Explained var: 0.18291731116652044
# correlation: [[0.43437056]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.022000
# Explained var: 0.20578910322743293
# correlation: [[0.45485344]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.453594
# Explained var: 0.16140395835245724
# correlation: [[0.40302884]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.885764
# Explained var: 0.17878676754063427
# correlation: [[0.42806349]]
# ---- Permutation avg. explained variance: 0.1815678486083131----
# Permutation: 25
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.487265
# Explained var: 0.15835946162279602
# correlation: [[0.39796512]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.216287
# Explained var: 0.1481033043471578
# correlation: [[0.38722884]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.523451
# Explained var: 0.13460524094354154
# correlation: [[0.3693228]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.818273
# Explained var: 0.24544971437529994
# correlation: [[0.50236589]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.477811
# Explained var: 0.15467888863166557
# correlation: [[0.39810064]]
# ---- Permutation avg. explained variance: 0.16823932198409217----
# Permutation: 26
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.540883
# Explained var: 0.20682703314060025
# correlation: [[0.46598395]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.254567
# Explained var: 0.15318446249995543
# correlation: [[0.39858888]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.611530
# Explained var: 0.18698734310323228
# correlation: [[0.43604522]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.555875
# Explained var: 0.20332924449593137
# correlation: [[0.45259204]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.662148
# Explained var: 0.07640461220213568
# correlation: [[0.2954859]]
# ---- Permutation avg. explained variance: 0.165346539088371----
# Permutation: 27
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.570917
# Explained var: 0.15031983533308146
# correlation: [[0.38774765]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.397313
# Explained var: 0.18947230632751688
# correlation: [[0.43566914]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.760223
# Explained var: 0.12531419769004482
# correlation: [[0.36921786]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.840098
# Explained var: 0.22202013391567454
# correlation: [[0.47798801]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.470972
# Explained var: 0.2051248685312307
# correlation: [[0.45453516]]
# ---- Permutation avg. explained variance: 0.17845026835950967----
# Permutation: 28
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.412767
# Explained var: 0.182665123969024
# correlation: [[0.42786145]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.404486
# Explained var: 0.2161972702414885
# correlation: [[0.47213347]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.545052
# Explained var: 0.20183519037714748
# correlation: [[0.44931581]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.777989
# Explained var: 0.1262620676162377
# correlation: [[0.36342655]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.424685
# Explained var: 0.22086054462261218
# correlation: [[0.47211312]]
# ---- Permutation avg. explained variance: 0.18956403936530197----
# Permutation: 29
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.744443
# Explained var: 0.20228733227610118
# correlation: [[0.46265385]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.524802
# Explained var: 0.14523308551714875
# correlation: [[0.39002761]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.386257
# Explained var: 0.22983114084352052
# correlation: [[0.48206436]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.723470
# Explained var: 0.12473170051003324
# correlation: [[0.36292289]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.451111
# Explained var: 0.10081548891952252
# correlation: [[0.38907202]]
# ---- Permutation avg. explained variance: 0.16057974961326524----
# Permutation: 30
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.476518
# Explained var: 0.17135868106179297
# correlation: [[0.42415436]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.436336
# Explained var: 0.16383912581207816
# correlation: [[0.40888923]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.725792
# Explained var: 0.12797081933284293
# correlation: [[0.36557299]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.771153
# Explained var: 0.12167429433462174
# correlation: [[0.35772585]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.010732
# Explained var: 0.23538740653057555
# correlation: [[0.53550899]]
# ---- Permutation avg. explained variance: 0.16404606541438227----
# Permutation: 31
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.857784
# Explained var: 0.20333218842519418
# correlation: [[0.45248981]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.769370
# Explained var: 0.12413202158026593
# correlation: [[0.36386975]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.474455
# Explained var: 0.136815207187567
# correlation: [[0.37726286]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.313261
# Explained var: 0.23521940193289015
# correlation: [[0.49822415]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.765939
# Explained var: 0.11009875345890541
# correlation: [[0.3487815]]
# ---- Permutation avg. explained variance: 0.16191951451696454----
# Permutation: 32
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.463069
# Explained var: 0.1363016535028435
# correlation: [[0.36920554]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.911356
# Explained var: 0.09652963029435313
# correlation: [[0.31740656]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.667778
# Explained var: 0.040221025169600466
# correlation: [[0.32033214]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.513787
# Explained var: 0.22352310351726712
# correlation: [[0.47340282]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.442680
# Explained var: 0.22866437667086903
# correlation: [[0.47873279]]
# ---- Permutation avg. explained variance: 0.14504795783098665----
# Permutation: 33
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.323400
# Explained var: 0.1403007330225532
# correlation: [[0.37745285]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.572253
# Explained var: 0.09295197264274391
# correlation: [[0.31499164]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.477143
# Explained var: 0.2192954115656297
# correlation: [[0.47019107]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.550651
# Explained var: 0.13061715866629287
# correlation: [[0.3760849]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.614253
# Explained var: 0.29425153525679915
# correlation: [[0.5570413]]
# ---- Permutation avg. explained variance: 0.17548336223080377----
# Permutation: 34
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.339108
# Explained var: 0.19684804637238174
# correlation: [[0.44437391]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.667406
# Explained var: 0.28724665353980294
# correlation: [[0.56247396]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.595408
# Explained var: 0.10207194673675779
# correlation: [[0.33984119]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.399409
# Explained var: 0.126777178530726
# correlation: [[0.37502137]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.593282
# Explained var: 0.19429315464555708
# correlation: [[0.44092405]]
# ---- Permutation avg. explained variance: 0.1814473959650451----
# Permutation: 35
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:10.371790
# Explained var: 0.063983864387812
# correlation: [[0.2860982]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.433603
# Explained var: 0.23963169076991053
# correlation: [[0.50270698]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.606713
# Explained var: 0.171993389129652
# correlation: [[0.43234916]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.477050
# Explained var: 0.20506421383489237
# correlation: [[0.45476165]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.916338
# Explained var: 0.189429241303824
# correlation: [[0.44565257]]
# ---- Permutation avg. explained variance: 0.17402047988521818----
# Permutation: 36
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.300013
# Explained var: 0.14347785757226295
# correlation: [[0.39820546]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.478141
# Explained var: 0.23405780929542697
# correlation: [[0.50266471]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.385609
# Explained var: 0.23925188003943587
# correlation: [[0.50729567]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.829384
# Explained var: 0.10346057417169918
# correlation: [[0.34895077]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.676793
# Explained var: 0.1695842798028504
# correlation: [[0.41313484]]
# ---- Permutation avg. explained variance: 0.17796648017633507----
# Permutation: 37
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.772332
# Explained var: 0.1562752538524358
# correlation: [[0.39602964]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.511787
# Explained var: 0.08096032770041428
# correlation: [[0.32298399]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.488791
# Explained var: 0.21527683367985573
# correlation: [[0.46788706]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.598278
# Explained var: 0.13945840621043526
# correlation: [[0.37750934]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.214344
# Explained var: 0.277280386043395
# correlation: [[0.54164102]]
# ---- Permutation avg. explained variance: 0.1738502414973072----
# Permutation: 38
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.796150
# Explained var: 0.2520119953236548
# correlation: [[0.52794407]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.744991
# Explained var: -0.05374302798245534
# correlation: [[0.18099637]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.756373
# Explained var: 0.2533021868160036
# correlation: [[0.50673125]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.655081
# Explained var: 0.30000891660304163
# correlation: [[0.56309834]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.689808
# Explained var: 0.19128912302265644
# correlation: [[0.43742308]]
# ---- Permutation avg. explained variance: 0.18857383875658024----
# Permutation: 39
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.482560
# Explained var: 0.18862835913413678
# correlation: [[0.43432358]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.652406
# Explained var: 0.2354242706306966
# correlation: [[0.49013897]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.412784
# Explained var: 0.21549085560032855
# correlation: [[0.47232164]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.627000
# Explained var: 0.12427179274903166
# correlation: [[0.35825099]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.579048
# Explained var: 0.1634553946250027
# correlation: [[0.40798528]]
# ---- Permutation avg. explained variance: 0.18545413454783927----
# Permutation: 40
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.775877
# Explained var: 0.15279670394380718
# correlation: [[0.39108559]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.524404
# Explained var: 0.1802721394942599
# correlation: [[0.42516196]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.313359
# Explained var: 0.21668409624305596
# correlation: [[0.47413157]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.487777
# Explained var: 0.2863617903147524
# correlation: [[0.54095101]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.479223
# Explained var: 0.1283585237063527
# correlation: [[0.3584987]]
# ---- Permutation avg. explained variance: 0.19289465074044562----
# Permutation: 41
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.457957
# Explained var: 0.14790991201877712
# correlation: [[0.39094729]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.666847
# Explained var: 0.1312871981002175
# correlation: [[0.37762959]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.864206
# Explained var: 0.22994150017905202
# correlation: [[0.48173992]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.642240
# Explained var: 0.22226410505556504
# correlation: [[0.47881118]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.740919
# Explained var: 0.15967173408764357
# correlation: [[0.40081679]]
# ---- Permutation avg. explained variance: 0.17821488988825104----
# Permutation: 42
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.470523
# Explained var: 0.24839115795812294
# correlation: [[0.51155291]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:09.512330
# Explained var: 0.16852506950272073
# correlation: [[0.41263274]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:09.700284
# Explained var: 0.1419560162412108
# correlation: [[0.37790917]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:27.455259
# Explained var: 0.19421734128383983
# correlation: [[0.46979628]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# ...
# correlation: [[0.53375406]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:52.099512
# Explained var: 0.10147777259328006
# correlation: [[0.32241499]]
# ---- Permutation avg. explained variance: 0.18409608847044084----
# Permutation: 86
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:52.370006
# Explained var: 0.2023096980175989
# correlation: [[0.4507849]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:53.135573
# Explained var: 0.21750411440891992
# correlation: [[0.47038716]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:52.133385
# Explained var: 0.2564228650775301
# correlation: [[0.51225277]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:52.935885
# Explained var: 0.16207853934938843
# correlation: [[0.40298336]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:52.847799
# Explained var: 0.04550136858860421
# correlation: [[0.27543505]]
# ---- Permutation avg. explained variance: 0.1767633170884083----
# Permutation: 87
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:51.320691
# Explained var: 0.1731911041939831
# correlation: [[0.416201]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:53.270454
# Explained var: 0.2052130992030542
# correlation: [[0.45873852]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:54.267200
# Explained var: 0.07144353788252311
# correlation: [[0.3071609]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:51.279711
# Explained var: 0.2560809509959763
# correlation: [[0.51205256]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:52.278987
# Explained var: 0.19715508112617108
# correlation: [[0.45248472]]
# ---- Permutation avg. explained variance: 0.18061675468034155----
# Permutation: 88
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:53.464043
# Explained var: 0.30520225008200375
# correlation: [[0.58077158]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:53.936556
# Explained var: 0.1758367189748633
# correlation: [[0.41933495]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:54.115651
# Explained var: 0.06097340931716544
# correlation: [[0.27027373]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:53.035954
# Explained var: 0.21351173601651152
# correlation: [[0.46361457]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:52.608773
# Explained var: 0.10574513554323894
# correlation: [[0.34294422]]
# ---- Permutation avg. explained variance: 0.17225384998675658----
# Permutation: 89
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:53.652707
# Explained var: 0.07869713037302073
# correlation: [[0.30492006]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:52.725336
# Explained var: 0.2592642788937013
# correlation: [[0.51257652]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:53.248608
# Explained var: 0.30230887242971494
# correlation: [[0.56392278]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:52.308309
# Explained var: 0.11340864109120541
# correlation: [[0.34113117]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:53.112514
# Explained var: 0.21420915597755363
# correlation: [[0.46978321]]
# ---- Permutation avg. explained variance: 0.1935776157530392----
# Permutation: 90
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:52.821384
# Explained var: 0.24616402651324887
# correlation: [[0.5138444]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:51.248982
# Explained var: 0.2371847862927997
# correlation: [[0.49179283]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:51.009881
# Explained var: 0.1180012228261269
# correlation: [[0.34467758]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:52.619277
# Explained var: 0.13248495873674204
# correlation: [[0.36761744]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:52.232952
# Explained var: 0.15543743898655638
# correlation: [[0.39898046]]
# ---- Permutation avg. explained variance: 0.17785448667109477----
# Permutation: 91
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:53.577855
# Explained var: 0.13677938908547338
# correlation: [[0.38578861]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:53.140498
# Explained var: 0.1952129042946854
# correlation: [[0.44431469]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:52.857232
# Explained var: 0.17187679874626471
# correlation: [[0.41458159]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:52.204288
# Explained var: 0.22306683600827892
# correlation: [[0.47549939]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:51.369775
# Explained var: 0.19435953810572582
# correlation: [[0.44093864]]
# ---- Permutation avg. explained variance: 0.18425909324808565----
# Permutation: 92
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:53.820888
# Explained var: 0.1432297552496986
# correlation: [[0.39288794]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:52.750209
# Explained var: 0.24203283595772151
# correlation: [[0.50122451]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:52.652617
# Explained var: 0.15717401139329545
# correlation: [[0.39671667]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:51.954607
# Explained var: 0.18929179184884315
# correlation: [[0.4351452]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:51.285670
# Explained var: 0.19359225527143686
# correlation: [[0.44021564]]
# ---- Permutation avg. explained variance: 0.18506412994419913----
# Permutation: 93
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:31.913304
# Explained var: 0.1807028700825909
# correlation: [[0.43072766]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:33.375571
# Explained var: 0.1848138438930007
# correlation: [[0.44477373]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:32.196566
# Explained var: 0.050560068201372044
# correlation: [[0.30664709]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:32.769338
# Explained var: 0.20411495119799827
# correlation: [[0.45338966]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:34.165764
# Explained var: 0.22621468877367812
# correlation: [[0.47760988]]
# ---- Permutation avg. explained variance: 0.169281284429728----
# Permutation: 94
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:33.018562
# Explained var: 0.04614381406215373
# correlation: [[0.278632]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:32.963937
# Explained var: 0.2051698258740784
# correlation: [[0.46357557]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:33.039555
# Explained var: 0.23192706348380276
# correlation: [[0.48284723]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:33.873552
# Explained var: 0.19075161056683276
# correlation: [[0.43675357]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:31.116577
# Explained var: 0.1901425643111665
# correlation: [[0.43745332]]
# ---- Permutation avg. explained variance: 0.17282697565960684----
# Permutation: 95
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:31.633495
# Explained var: 0.2759070765990467
# correlation: [[0.52577439]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:31.476329
# Explained var: 0.10340940695971268
# correlation: [[0.33068132]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:33.993062
# Explained var: 0.1453369199509139
# correlation: [[0.3814324]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:32.626299
# Explained var: 0.20187684838295017
# correlation: [[0.46020733]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:33.200213
# Explained var: 0.15066827334932298
# correlation: [[0.38845614]]
# ---- Permutation avg. explained variance: 0.1754397050483893----
# Permutation: 96
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:31.506884
# Explained var: 0.2618743405493451
# correlation: [[0.52143916]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:29.224344
# Explained var: 0.18198294029522233
# correlation: [[0.4291411]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:31.424967
# Explained var: 0.1828581091685938
# correlation: [[0.42815619]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:30.011347
# Explained var: 0.12826233911493057
# correlation: [[0.36780745]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:29.957717
# Explained var: 0.10914501533285526
# correlation: [[0.34733253]]
# ---- Permutation avg. explained variance: 0.1728245488921894----
# Permutation: 97
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:31.245198
# Explained var: 0.26645124430078526
# correlation: [[0.53846429]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:28.679140
# Explained var: 0.25267336645493255
# correlation: [[0.51514346]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:32.261733
# Explained var: 0.18826864789842246
# correlation: [[0.4385997]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:34.883544
# Explained var: 0.09823651383032883
# correlation: [[0.33199001]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:32.409773
# Explained var: 0.12383774415534077
# correlation: [[0.35605636]]
# ---- Permutation avg. explained variance: 0.18589350332796198----
# Permutation: 98
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:33.787367
# Explained var: 0.09823609927341981
# correlation: [[0.34333813]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:33.734677
# Explained var: 0.1483330891246779
# correlation: [[0.3902185]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:34.729037
# Explained var: 0.2288105992657845
# correlation: [[0.48489669]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:33.553818
# Explained var: 0.16497565503171185
# correlation: [[0.41031481]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:33.052496
# Explained var: 0.25754143247314554
# correlation: [[0.51923053]]
# ---- Permutation avg. explained variance: 0.17957937503374793----
# Permutation: 99
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:33.934244
# Explained var: 0.23020022446359678
# correlation: [[0.48927778]]
# 5-fold cross-validation results in 400.8 subjects in the training set, and 100.2 subjects in the validation set
# time to run loop: 0:00:32.573279
# Explained var: 0.19719936913891523
# correlation: [[0.44884087]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:31.320660
# Explained var: 0.22230043773891306
# correlation: [[0.48376973]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:32.172798
# Explained var: 0.05959014133143781
# correlation: [[0.2798252]]
# 5-fold cross-validation results in 401.6 subjects in the training set, and 100.4 subjects in the validation set
# time to run loop: 0:00:32.274288
# Explained var: 0.18578409960596287
# correlation: [[0.43800755]]
# ---- Permutation avg. explained variance: 0.17901485445576515----

# %%
# Haufe transformation of feature weights
k=5
Y = np.array(fuglmeyer)

perm=0
fullactivations=[] 
#iterate through permutations
for p in range(0,100):
    k=5
    
    # load activation weights
    with open(results_dir + 'correlation' + 'p' + str(p) + '_SC_varimpt.pkl', 'rb') as f:
        activ = pickle.load(f)
        
    outer_cv = KFold(n_splits=k, shuffle=True, random_state=p)
    
    # Load features selected from permutation
    with open(results_dir + 'correlation' + 'p' + str(p) + '_SC_features.pkl', 'rb') as f:
        feats = pickle.load(f)
    
    c=0   
    activations=[]
    X=sc

    fullactivation=[]
    activationweight=[]
    for train, test in outer_cv.split(X):
        x_train=X[train]
        X=x_train
        X_sub=X[:,feats[c][:]]
        
        X_sub=np.reshape(X_sub, [len(train),feats[c].shape[0]])
        cov_x=np.cov(np.transpose(X_sub))
        
        print(X_sub.shape)
        if feats[c].shape[0]==1:
            cov_x=np.reshape(cov_x, [1,1])
        
    
        cov_y=np.cov(np.transpose(Y[train]))
    
        activationweight=activ[c]

        #print(activationweight.shape)
        weight=np.transpose(activationweight)

        print(cov_x.shape)
        print(weight.shape)
        print(cov_y.shape)
        activation=np.matmul(cov_x,weight)*(1/cov_y)
        activations.append(activation)
        #print(activation.shape)

        # get activation weights back to matrix form 86x86
        # get indices of weights not selected as features; set weight to 0    
        idx=np.ones(shape=(86,1), dtype='bool')
        idx[feats[c]]=False # set SC weights that are features to be 1
        idx=idx.flatten()
        zeroidx=np.arange(0, 86, dtype='int')
        zeroidx=zeroidx[idx]
        
        # fill spots with 0's (up to 3192)
        k=0
        activation_full = activation
        while k < zeroidx.shape[0]:
            activation_full=np.insert(activation_full, zeroidx[k],0)
            k=k+1
        
        #print("Full 3192: " + str(np.sum(activation_full>0)))
        # fill spots with 0's (up to 3655)
        X=sc
        zeros=sc==0
        zeros=np.sum(zeros,0) # number of zeros across subjects
        zeros=zeros==X.shape[0] # find columns with zeros for all 101 subjects
        X=X[:,~zeros]
        
        zeroidx=np.arange(0, 86)
        zeroidx=zeroidx[zeros]

        # fill spots with 0's
        k=0
        a = activation_full
        while k < zeroidx.shape[0]:
            a=np.insert(a, zeroidx[k],0)
            k=k+1
        
        #print("Full 268: " + str(np.sum(a>0)))
        fullactivation.append(a)
        c=c+1
         
    fullactivations.append(fullactivation)
# Out:
# (501, 59)
# (59, 59)
# (59, 1)
# ()
# (501, 34)
# (34, 34)
# (34, 1)
# ()
# (502, 44)
# (44, 44)
# (44, 1)
# ()
# (502, 36)
# (36, 36)
# (36, 1)
# ()
# (502, 53)
# (53, 53)
# (53, 1)
# ()
# (501, 56)
# (56, 56)
# (56, 1)
# ()
# (501, 45)
# (45, 45)
# (45, 1)
# ()
# (502, 71)
# (71, 71)
# (71, 1)
# ()
# (502, 49)
# (49, 49)
# (49, 1)
# ()
# (502, 67)
# (67, 67)
# (67, 1)
# ()
# (501, 69)
# (69, 69)
# (69, 1)
# ()
# (501, 85)
# (85, 85)
# (85, 1)
# ()
# (502, 55)
# (55, 55)
# (55, 1)
# ()
# (502, 64)
# (64, 64)
# (64, 1)
# ()
# (502, 32)
# (32, 32)
# (32, 1)
# ()
# (501, 39)
# (39, 39)
# (39, 1)
# ()
# (501, 73)
# (73, 73)
# (73, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 53)
# (53, 53)
# (53, 1)
# ()
# (502, 31)
# (31, 31)
# (31, 1)
# ()
# (501, 44)
# (44, 44)
# (44, 1)
# ()
# (501, 81)
# (81, 81)
# (81, 1)
# ()
# (502, 32)
# (32, 32)
# (32, 1)
# ()
# (502, 38)
# (38, 38)
# (38, 1)
# ()
# (502, 85)
# (85, 85)
# (85, 1)
# ()
# (501, 35)
# (35, 35)
# (35, 1)
# ()
# (501, 57)
# (57, 57)
# (57, 1)
# ()
# (502, 41)
# (41, 41)
# (41, 1)
# ()
# (502, 54)
# (54, 54)
# (54, 1)
# ()
# (502, 37)
# (37, 37)
# (37, 1)
# ()
# (501, 30)
# (30, 30)
# (30, 1)
# ()
# (501, 37)
# (37, 37)
# (37, 1)
# ()
# (502, 55)
# (55, 55)
# (55, 1)
# ()
# (502, 76)
# (76, 76)
# (76, 1)
# ()
# (502, 36)
# (36, 36)
# (36, 1)
# ()
# (501, 69)
# (69, 69)
# (69, 1)
# ()
# (501, 31)
# (31, 31)
# (31, 1)
# ()
# (502, 50)
# (50, 50)
# (50, 1)
# ()
# (502, 32)
# (32, 32)
# (32, 1)
# ()
# (502, 39)
# (39, 39)
# (39, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 73)
# (73, 73)
# (73, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 44)
# (44, 44)
# (44, 1)
# ()
# (501, 85)
# (85, 85)
# (85, 1)
# ()
# (501, 64)
# (64, 64)
# (64, 1)
# ()
# (502, 33)
# (33, 33)
# (33, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 61)
# (61, 61)
# (61, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 43)
# (43, 43)
# (43, 1)
# ()
# (502, 36)
# (36, 36)
# (36, 1)
# ()
# (502, 53)
# (53, 53)
# (53, 1)
# ()
# (501, 55)
# (55, 55)
# (55, 1)
# ()
# (501, 41)
# (41, 41)
# (41, 1)
# ()
# (502, 21)
# (21, 21)
# (21, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 49)
# (49, 49)
# (49, 1)
# ()
# (501, 40)
# (40, 40)
# (40, 1)
# ()
# (501, 54)
# (54, 54)
# (54, 1)
# ()
# (502, 77)
# (77, 77)
# (77, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 51)
# (51, 51)
# (51, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 84)
# (84, 84)
# (84, 1)
# ()
# (502, 31)
# (31, 31)
# (31, 1)
# ()
# (502, 85)
# (85, 85)
# (85, 1)
# ()
# (502, 34)
# (34, 34)
# (34, 1)
# ()
# (501, 47)
# (47, 47)
# (47, 1)
# ()
# (501, 32)
# (32, 32)
# (32, 1)
# ()
# (502, 43)
# (43, 43)
# (43, 1)
# ()
# (502, 81)
# (81, 81)
# (81, 1)
# ()
# (502, 68)
# (68, 68)
# (68, 1)
# ()
# (501, 76)
# (76, 76)
# (76, 1)
# ()
# (501, 50)
# (50, 50)
# (50, 1)
# ()
# (502, 72)
# (72, 72)
# (72, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 42)
# (42, 42)
# (42, 1)
# ()
# (501, 72)
# (72, 72)
# (72, 1)
# ()
# (501, 66)
# (66, 66)
# (66, 1)
# ()
# (502, 54)
# (54, 54)
# (54, 1)
# ()
# (502, 29)
# (29, 29)
# (29, 1)
# ()
# (502, 63)
# (63, 63)
# (63, 1)
# ()
# (501, 43)
# (43, 43)
# (43, 1)
# ()
# (501, 42)
# (42, 42)
# (42, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 32)
# (32, 32)
# (32, 1)
# ()
# (502, 85)
# (85, 85)
# (85, 1)
# ()
# (501, 29)
# (29, 29)
# (29, 1)
# ()
# (501, 31)
# (31, 31)
# (31, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 39)
# (39, 39)
# (39, 1)
# ()
# (502, 30)
# (30, 30)
# (30, 1)
# ()
# (501, 43)
# (43, 43)
# (43, 1)
# ()
# (501, 69)
# (69, 69)
# (69, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 81)
# (81, 81)
# (81, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 84)
# (84, 84)
# (84, 1)
# ()
# (501, 28)
# (28, 28)
# (28, 1)
# ()
# (502, 47)
# (47, 47)
# (47, 1)
# ()
# (502, 35)
# (35, 35)
# (35, 1)
# ()
# (502, 40)
# (40, 40)
# (40, 1)
# ()
# (501, 31)
# (31, 31)
# (31, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 63)
# (63, 63)
# (63, 1)
# ()
# (502, 56)
# (56, 56)
# (56, 1)
# ()
# (502, 50)
# (50, 50)
# (50, 1)
# ()
# (501, 84)
# (84, 84)
# (84, 1)
# ()
# (501, 81)
# (81, 81)
# (81, 1)
# ()
# (502, 40)
# (40, 40)
# (40, 1)
# ()
# (502, 49)
# (49, 49)
# (49, 1)
# ()
# (502, 50)
# (50, 50)
# (50, 1)
# ()
# (501, 37)
# (37, 37)
# (37, 1)
# ()
# (501, 33)
# (33, 33)
# (33, 1)
# ()
# (502, 33)
# (33, 33)
# (33, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 25)
# (25, 25)
# (25, 1)
# ()
# (501, 52)
# (52, 52)
# (52, 1)
# ()
# (501, 82)
# (82, 82)
# (82, 1)
# ()
# (502, 26)
# (26, 26)
# (26, 1)
# ()
# (502, 77)
# (77, 77)
# (77, 1)
# ()
# (502, 40)
# (40, 40)
# (40, 1)
# ()
# (501, 42)
# (42, 42)
# (42, 1)
# ()
# (501, 42)
# (42, 42)
# (42, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 49)
# (49, 49)
# (49, 1)
# ()
# (502, 83)
# (83, 83)
# (83, 1)
# ()
# (501, 63)
# (63, 63)
# (63, 1)
# ()
# (501, 71)
# (71, 71)
# (71, 1)
# ()
# (502, 44)
# (44, 44)
# (44, 1)
# ()
# (502, 25)
# (25, 25)
# (25, 1)
# ()
# (502, 45)
# (45, 45)
# (45, 1)
# ()
# (501, 70)
# (70, 70)
# (70, 1)
# ()
# (501, 38)
# (38, 38)
# (38, 1)
# ()
# (502, 53)
# (53, 53)
# (53, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 34)
# (34, 34)
# (34, 1)
# ()
# (501, 34)
# (34, 34)
# (34, 1)
# ()
# (501, 39)
# (39, 39)
# (39, 1)
# ()
# (502, 42)
# (42, 42)
# (42, 1)
# ()
# (502, 41)
# (41, 41)
# (41, 1)
# ()
# (502, 52)
# (52, 52)
# (52, 1)
# ()
# (501, 45)
# (45, 45)
# (45, 1)
# ()
# (501, 43)
# (43, 43)
# (43, 1)
# ()
# (502, 32)
# (32, 32)
# (32, 1)
# ()
# (502, 33)
# (33, 33)
# (33, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 45)
# (45, 45)
# (45, 1)
# ()
# (501, 27)
# (27, 27)
# (27, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 31)
# (31, 31)
# (31, 1)
# ()
# (502, 39)
# (39, 39)
# (39, 1)
# ()
# (501, 36)
# (36, 36)
# (36, 1)
# ()
# (501, 81)
# (81, 81)
# (81, 1)
# ()
# (502, 51)
# (51, 51)
# (51, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 36)
# (36, 36)
# (36, 1)
# ()
# (501, 77)
# (77, 77)
# (77, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 22)
# (22, 22)
# (22, 1)
# ()
# (502, 51)
# (51, 51)
# (51, 1)
# ()
# (502, 83)
# (83, 83)
# (83, 1)
# ()
# (501, 55)
# (55, 55)
# (55, 1)
# ()
# (501, 69)
# (69, 69)
# (69, 1)
# ()
# (502, 36)
# (36, 36)
# (36, 1)
# ()
# (502, 62)
# (62, 62)
# (62, 1)
# ()
# (502, 34)
# (34, 34)
# (34, 1)
# ()
# (501, 55)
# (55, 55)
# (55, 1)
# ()
# (501, 33)
# (33, 33)
# (33, 1)
# ()
# (502, 44)
# (44, 44)
# (44, 1)
# ()
# (502, 41)
# (41, 41)
# (41, 1)
# ()
# (502, 59)
# (59, 59)
# (59, 1)
# ()
# (501, 51)
# (51, 51)
# (51, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 44)
# (44, 44)
# (44, 1)
# ()
# (502, 32)
# (32, 32)
# (32, 1)
# ()
# (502, 49)
# (49, 49)
# (49, 1)
# ()
# (501, 45)
# (45, 45)
# (45, 1)
# ()
# (501, 84)
# (84, 84)
# (84, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 43)
# (43, 43)
# (43, 1)
# ()
# (502, 39)
# (39, 39)
# (39, 1)
# ()
# (501, 35)
# (35, 35)
# (35, 1)
# ()
# (501, 42)
# (42, 42)
# (42, 1)
# ()
# (502, 40)
# (40, 40)
# (40, 1)
# ()
# (502, 33)
# (33, 33)
# (33, 1)
# ()
# (502, 41)
# (41, 41)
# (41, 1)
# ()
# (501, 85)
# (85, 85)
# (85, 1)
# ()
# (501, 49)
# (49, 49)
# (49, 1)
# ()
# (502, 45)
# (45, 45)
# (45, 1)
# ()
# (502, 66)
# (66, 66)
# (66, 1)
# ()
# (502, 39)
# (39, 39)
# (39, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 54)
# (54, 54)
# (54, 1)
# ()
# (502, 39)
# (39, 39)
# (39, 1)
# ()
# (502, 34)
# (34, 34)
# (34, 1)
# ()
# (502, 69)
# (69, 69)
# (69, 1)
# ()
# (501, 82)
# (82, 82)
# (82, 1)
# ()
# (501, 54)
# (54, 54)
# (54, 1)
# ()
# (502, 52)
# (52, 52)
# (52, 1)
# ()
# (502, 31)
# (31, 31)
# (31, 1)
# ()
# (502, 41)
# (41, 41)
# (41, 1)
# ()
# (501, 34)
# (34, 34)
# (34, 1)
# ()
# (501, 38)
# (38, 38)
# (38, 1)
# ()
# (502, 37)
# (37, 37)
# (37, 1)
# ()
# (502, 52)
# (52, 52)
# (52, 1)
# ()
# (502, 68)
# (68, 68)
# (68, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 47)
# (47, 47)
# (47, 1)
# ()
# (502, 49)
# (49, 49)
# (49, 1)
# ()
# (502, 71)
# (71, 71)
# (71, 1)
# ()
# (501, 63)
# (63, 63)
# (63, 1)
# ()
# (501, 33)
# (33, 33)
# (33, 1)
# ()
# (502, 65)
# (65, 65)
# (65, 1)
# ()
# (502, 85)
# (85, 85)
# (85, 1)
# ()
# (502, 44)
# (44, 44)
# (44, 1)
# ()
# (501, 30)
# (30, 30)
# (30, 1)
# ()
# (501, 45)
# (45, 45)
# (45, 1)
# ()
# (502, 41)
# (41, 41)
# (41, 1)
# ()
# (502, 40)
# (40, 40)
# (40, 1)
# ()
# (502, 68)
# (68, 68)
# (68, 1)
# ()
# (501, 40)
# (40, 40)
# (40, 1)
# ()
# (501, 43)
# (43, 43)
# (43, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 45)
# (45, 45)
# (45, 1)
# ()
# (502, 50)
# (50, 50)
# (50, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 53)
# (53, 53)
# (53, 1)
# ()
# (502, 49)
# (49, 49)
# (49, 1)
# ()
# (502, 85)
# (85, 85)
# (85, 1)
# ()
# (502, 37)
# (37, 37)
# (37, 1)
# ()
# (501, 54)
# (54, 54)
# (54, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 47)
# (47, 47)
# (47, 1)
# ()
# (502, 41)
# (41, 41)
# (41, 1)
# ()
# (502, 68)
# (68, 68)
# (68, 1)
# ()
# (501, 81)
# (81, 81)
# (81, 1)
# ()
# (501, 41)
# (41, 41)
# (41, 1)
# ()
# (502, 61)
# (61, 61)
# (61, 1)
# ()
# (502, 85)
# (85, 85)
# (85, 1)
# ()
# (502, 33)
# (33, 33)
# (33, 1)
# ()
# (501, 68)
# (68, 68)
# (68, 1)
# ()
# (501, 37)
# (37, 37)
# (37, 1)
# ()
# (502, 57)
# (57, 57)
# (57, 1)
# ()
# (502, 35)
# (35, 35)
# (35, 1)
# ()
# (502, 48)
# (48, 48)
# (48, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 85)
# (85, 85)
# (85, 1)
# ()
# (502, 55)
# (55, 55)
# (55, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 77)
# (77, 77)
# (77, 1)
# ()
# (501, 43)
# (43, 43)
# (43, 1)
# ()
# (501, 84)
# (84, 84)
# (84, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 72)
# (72, 72)
# (72, 1)
# ()
# (502, 29)
# (29, 29)
# (29, 1)
# ()
# (501, 45)
# (45, 45)
# (45, 1)
# ()
# (501, 57)
# (57, 57)
# (57, 1)
# ()
# (502, 33)
# (33, 33)
# (33, 1)
# ()
# (502, 85)
# (85, 85)
# (85, 1)
# ()
# (502, 76)
# (76, 76)
# (76, 1)
# ()
# (501, 30)
# (30, 30)
# (30, 1)
# ()
# (501, 38)
# (38, 38)
# (38, 1)
# ()
# (502, 41)
# (41, 41)
# (41, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 43)
# (43, 43)
# (43, 1)
# ()
# (501, 71)
# (71, 71)
# (71, 1)
# ()
# (501, 49)
# (49, 49)
# (49, 1)
# ()
# (502, 35)
# (35, 35)
# (35, 1)
# ()
# (502, 80)
# (80, 80)
# (80, 1)
# ()
# (502, 36)
# (36, 36)
# (36, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 33)
# (33, 33)
# (33, 1)
# ()
# (502, 49)
# (49, 49)
# (49, 1)
# ()
# (502, 85)
# (85, 85)
# (85, 1)
# ()
# (502, 28)
# (28, 28)
# (28, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 31)
# (31, 31)
# (31, 1)
# ()
# (502, 32)
# (32, 32)
# (32, 1)
# ()
# (502, 40)
# (40, 40)
# (40, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 32)
# (32, 32)
# (32, 1)
# ()
# (501, 62)
# (62, 62)
# (62, 1)
# ()
# (502, 39)
# (39, 39)
# (39, 1)
# ()
# (502, 28)
# (28, 28)
# (28, 1)
# ()
# (502, 73)
# (73, 73)
# (73, 1)
# ()
# (501, 31)
# (31, 31)
# (31, 1)
# ()
# (501, 69)
# (69, 69)
# (69, 1)
# ()
# (502, 46)
# (46, 46)
# (46, 1)
# ()
# (502, 70)
# (70, 70)
# (70, 1)
# ()
# (502, 84)
# (84, 84)
# (84, 1)
# ()
# (501, 62)
# (62, 62)
# (62, 1)
# ()
# (501, 35)
# (35, 35)
# (35, 1)
# ()
# (502, 27)
# (27, 27)
# (27, 1)
# ()
# (502, 85)
# (85, 85)
# (85, 1)
# ()
# (502, 51)
# (51, 51)
# (51, 1)
# ()
# (501, 35)
# (35, 35)
# (35, 1)
# ()
# (501, 23)
# (23, 23)
# (23, 1)
# ()
# (502, 39)
# (39, 39)
# (39, 1)
# ()
# (502, 64)
# (64, 64)
# (64, 1)
# ()
# (502, 28)
# (28, 28)
# (28, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 43)
# (43, 43)
# (43, 1)
# ()
# (502, 67)
# (67, 67)
# (67, 1)
# ()
# (502, 36)
# (36, 36)
# (36, 1)
# ()
# (502, 52)
# (52, 52)
# (52, 1)
# ()
# (501, 61)
# (61, 61)
# (61, 1)
# ()
# (501, 30)
# (30, 30)
# (30, 1)
# ()
# (502, 31)
# (31, 31)
# (31, 1)
# ()
# (502, 57)
# (57, 57)
# (57, 1)
# ()
# (502, 32)
# (32, 32)
# (32, 1)
# ()
# (501, 85)
# (85, 85)
# (85, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 46)
# (46, 46)
# (46, 1)
# ()
# (502, 83)
# (83, 83)
# (83, 1)
# ()
# (502, 49)
# (49, 49)
# (49, 1)
# ()
# (501, 56)
# (56, 56)
# (56, 1)
# ()
# (501, 44)
# (44, 44)
# (44, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 39)
# (39, 39)
# (39, 1)
# ()
# (501, 66)
# (66, 66)
# (66, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 33)
# (33, 33)
# (33, 1)
# ()
# (502, 34)
# (34, 34)
# (34, 1)
# ()
# (502, 41)
# (41, 41)
# (41, 1)
# ()
# (501, 71)
# (71, 71)
# (71, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 48)
# (48, 48)
# (48, 1)
# ()
# (502, 39)
# (39, 39)
# (39, 1)
# ()
# (502, 28)
# (28, 28)
# (28, 1)
# ()
# (501, 82)
# (82, 82)
# (82, 1)
# ()
# (501, 66)
# (66, 66)
# (66, 1)
# ()
# (502, 36)
# (36, 36)
# (36, 1)
# ()
# (502, 85)
# (85, 85)
# (85, 1)
# ()
# (502, 40)
# (40, 40)
# (40, 1)
# ()
# (501, 40)
# (40, 40)
# (40, 1)
# ()
# (501, 27)
# (27, 27)
# (27, 1)
# ()
# (502, 36)
# (36, 36)
# (36, 1)
# ()
# (502, 35)
# (35, 35)
# (35, 1)
# ()
# (502, 69)
# (69, 69)
# (69, 1)
# ()
# (501, 45)
# (45, 45)
# (45, 1)
# ()
# (501, 31)
# (31, 31)
# (31, 1)
# ()
# (502, 67)
# (67, 67)
# (67, 1)
# ()
# (502, 84)
# (84, 84)
# (84, 1)
# ()
# (502, 56)
# (56, 56)
# (56, 1)
# ()
# (501, 43)
# (43, 43)
# (43, 1)
# ()
# (501, 63)
# (63, 63)
# (63, 1)
# ()
# (502, 64)
# (64, 64)
# (64, 1)
# ()
# (502, 49)
# (49, 49)
# (49, 1)
# ()
# (502, 43)
# (43, 43)
# (43, 1)
# ()
# (501, 33)
# (33, 33)
# (33, 1)
# ()
# (501, 65)
# (65, 65)
# (65, 1)
# ()
# (502, 85)
# (85, 85)
# (85, 1)
# ()
# (502, 40)
# (40, 40)
# (40, 1)
# ()
# (502, 54)
# (54, 54)
# (54, 1)
# ()
# (501, 80)
# (80, 80)
# (80, 1)
# ()
# (501, 38)
# (38, 38)
# (38, 1)
# ()
# (502, 82)
# (82, 82)
# (82, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 42)
# (42, 42)
# (42, 1)
# ()
# (501, 85)
# (85, 85)
# (85, 1)
# ()
# (501, 43)
# (43, 43)
# (43, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 65)
# (65, 65)
# (65, 1)
# ()
# (501, 57)
# (57, 57)
# (57, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 47)
# (47, 47)
# (47, 1)
# ()
# (502, 35)
# (35, 35)
# (35, 1)
# ()
# (502, 31)
# (31, 31)
# (31, 1)
# ()
# (501, 39)
# (39, 39)
# (39, 1)
# ()
# (501, 60)
# (60, 60)
# (60, 1)
# ()
# (502, 29)
# (29, 29)
# (29, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 34)
# (34, 34)
# (34, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 71)
# (71, 71)
# (71, 1)
# ()
# (502, 39)
# (39, 39)
# (39, 1)
# ()
# (502, 34)
# (34, 34)
# (34, 1)
# ()
# (502, 84)
# (84, 84)
# (84, 1)
# ()
# (501, 79)
# (79, 79)
# (79, 1)
# ()
# (501, 39)
# (39, 39)
# (39, 1)
# ()
# (502, 51)
# (51, 51)
# (51, 1)
# ()
# (502, 84)
# (84, 84)
# (84, 1)
# ()
# (502, 59)
# (59, 59)
# (59, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 66)
# (66, 66)
# (66, 1)
# ()
# (502, 37)
# (37, 37)
# (37, 1)
# ()
# (502, 84)
# (84, 84)
# (84, 1)
# ()
# (502, 37)
# (37, 37)
# (37, 1)
# ()
# (501, 39)
# (39, 39)
# (39, 1)
# ()
# (501, 65)
# (65, 65)
# (65, 1)
# ()
# (502, 59)
# (59, 59)
# (59, 1)
# ()
# (502, 62)
# (62, 62)
# (62, 1)
# ()
# (502, 40)
# (40, 40)
# (40, 1)
# ()
# (501, 42)
# (42, 42)
# (42, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 50)
# (50, 50)
# (50, 1)
# ()
# (502, 63)
# (63, 63)
# (63, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 31)
# (31, 31)
# (31, 1)
# ()
# (501, 33)
# (33, 33)
# (33, 1)
# ()
# (502, 50)
# (50, 50)
# (50, 1)
# ()
# (502, 30)
# (30, 30)
# (30, 1)
# ()
# (502, 41)
# (41, 41)
# (41, 1)
# ()
# (501, 66)
# (66, 66)
# (66, 1)
# ()
# (501, 84)
# (84, 84)
# (84, 1)
# ()
# (502, 50)
# (50, 50)
# (50, 1)
# ()
# (502, 63)
# (63, 63)
# (63, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 51)
# (51, 51)
# (51, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 44)
# (44, 44)
# (44, 1)
# ()
# (502, 76)
# (76, 76)
# (76, 1)
# ()
# (501, 48)
# (48, 48)
# (48, 1)
# ()
# (501, 65)
# (65, 65)
# (65, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 72)
# (72, 72)
# (72, 1)
# ()
# (502, 33)
# (33, 33)
# (33, 1)
# ()
# (501, 85)
# (85, 85)
# (85, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 34)
# (34, 34)
# (34, 1)
# ()
# (502, 41)
# (41, 41)
# (41, 1)
# ()
# (502, 49)
# (49, 49)
# (49, 1)
# ()
# (501, 66)
# (66, 66)
# (66, 1)
# ()
# (501, 33)
# (33, 33)
# (33, 1)
# ()
# (502, 67)
# (67, 67)
# (67, 1)
# ()
# (502, 79)
# (79, 79)
# (79, 1)
# ()
# (502, 61)
# (61, 61)
# (61, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 73)
# (73, 73)
# (73, 1)
# ()
# (502, 38)
# (38, 38)
# (38, 1)
# ()
# (502, 68)
# (68, 68)
# (68, 1)
# ()
# (502, 81)
# (81, 81)
# (81, 1)
# ()
# (501, 26)
# (26, 26)
# (26, 1)
# ()
# (501, 78)
# (78, 78)
# (78, 1)
# ()
# (502, 48)
# (48, 48)
# (48, 1)
# ()
# (502, 28)
# (28, 28)
# (28, 1)
# ()
# (502, 70)
# (70, 70)
# (70, 1)
# ()
# (501, 39)
# (39, 39)
# (39, 1)
# ()
# (501, 48)
# (48, 48)
# (48, 1)
# ()
# (502, 41)
# (41, 41)
# (41, 1)
# ()
# (502, 59)
# (59, 59)
# (59, 1)
# ()
# (502, 43)
# (43, 43)
# (43, 1)
# ()
# (501, 62)
# (62, 62)
# (62, 1)
# ()
# (501, 70)
# (70, 70)
# (70, 1)
# ()
# (502, 51)
# (51, 51)
# (51, 1)
# ()
# (502, 50)
# (50, 50)
# (50, 1)
# ()
# (502, 75)
# (75, 75)
# (75, 1)
# ()
# (501, 33)
# (33, 33)
# (33, 1)
# ()
# (501, 37)
# (37, 37)
# (37, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 78)
# (78, 78)
# (78, 1)
# ()
# (502, 35)
# (35, 35)
# (35, 1)
# ()
# (501, 50)
# (50, 50)
# (50, 1)
# ()
# (501, 56)
# (56, 56)
# (56, 1)
# ()
# (502, 54)
# (54, 54)
# (54, 1)
# ()
# (502, 53)
# (53, 53)
# (53, 1)
# ()
# (502, 41)
# (41, 41)
# (41, 1)
# ()
# (501, 34)
# (34, 34)
# (34, 1)
# ()
# (501, 51)
# (51, 51)
# (51, 1)
# ()
# (502, 73)
# (73, 73)
# (73, 1)
# ()
# (502, 26)
# (26, 26)
# (26, 1)
# ()
# (502, 40)
# (40, 40)
# (40, 1)
# ()
# (501, 45)
# (45, 45)
# (45, 1)
# ()
# (501, 82)
# (82, 82)
# (82, 1)
# ()
# (502, 45)
# (45, 45)
# (45, 1)
# ()
# (502, 44)
# (44, 44)
# (44, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 38)
# (38, 38)
# (38, 1)
# ()
# (501, 35)
# (35, 35)
# (35, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (502, 25)
# (25, 25)
# (25, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 34)
# (34, 34)
# (34, 1)
# ()
# (501, 46)
# (46, 46)
# (46, 1)
# ()
# (502, 35)
# (35, 35)
# (35, 1)
# ()
# (502, 85)
# (85, 85)
# (85, 1)
# ()
# (502, 55)
# (55, 55)
# (55, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 73)
# (73, 73)
# (73, 1)
# ()
# (502, 40)
# (40, 40)
# (40, 1)
# ()
# (502, 32)
# (32, 32)
# (32, 1)
# ()
# (502, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 84)
# (84, 84)
# (84, 1)
# ()
# (501, 42)
# (42, 42)
# (42, 1)
# ()
# (502, 37)
# (37, 37)
# (37, 1)
# ()
# (502, 84)
# (84, 84)
# (84, 1)
# ()
# (502, 39)
# (39, 39)
# (39, 1)
# ()
# (501, 86)
# (86, 86)
# (86, 1)
# ()
# (501, 56)
# (56, 56)
# (56, 1)
# ()
# (502, 81)
# (81, 81)
# (81, 1)
# ()
# (502, 45)
# (45, 45)
# (45, 1)
# ()
# (502, 32)
# (32, 32)
# (32, 1)
# ()

# %%
# SC average across stroke subjects
from nilearn import datasets
from nilearn import plotting

# %%
fs86_activations=np.empty((86,)) 

for p in range(0,100):
    act=fullactivations[p] # features 
    for x in range(0,5):
        shen268_activations=np.vstack((fs86_activations, np.transpose(act[x])))
        
shen268_region=np.mean(shen268_activations[1:],axis=0)

coordinates = plotting.find_parcellation_cut_coords('/home/ubuntu/enigma/fs86_allsubj_mode2mm.nii.gz')
plotting.plot_markers(shen268_region, coordinates,node_size=40,
                         title='Activations',colorbar=True)

np.savetxt(results_dir + 'avgHaufe_fs86_regionalSDC_correlation_chronic.txt', shen268_region, delimiter=',')
np.savetxt(results_dir + 'allHaufe_fs86_regionalSDC_correlation_chronic.txt', shen268_activations[1:], delimiter=',')

# %%
shen268_activations
# Out:
# array([[ 6.92989860e-310,  6.92989860e-310,  4.68297925e-310, ...,
#         -5.68749510e-002, -6.32723847e-002,  0.00000000e+000],
#        [ 0.00000000e+000, -1.41107865e-002,  0.00000000e+000, ...,
#         -5.68749510e-002, -6.32723847e-002,  0.00000000e+000],
#        [ 0.00000000e+000, -2.07707475e-002,  0.00000000e+000, ...,
#         -7.83878577e-002,  0.00000000e+000,  0.00000000e+000],
#        ...,
#        [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#         -1.32597880e-001,  0.00000000e+000,  0.00000000e+000],
#        [ 0.00000000e+000, -3.75734457e-002,  0.00000000e+000, ...,
#         -1.75240258e-001,  0.00000000e+000,  0.00000000e+000],
#        [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#         -1.34711878e-001,  0.00000000e+000,  0.00000000e+000]])
