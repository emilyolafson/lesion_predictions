# %%
# check out models
from cgi import test
import numpy as np
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import RepeatedKFold,ShuffleSplit, GroupKFold, LeaveOneGroupOut, train_test_split, GridSearchCV, cross_val_score, KFold, StratifiedKFold

y_var = 'normed_motor_scores'
chaco_type = 'chacovol'
subset = 'chronic'
models_tested = ['ridge']
crossval ='2'
results_path = '/Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results' 
mdl_label = models_tested[0]

# %%
atlases = ['fs86subj', 'shen268']
chaco_types = ['chacovol']
crossval_types =['1', '5']
nperms = 25
filename
# Out:
# '/Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/shen268_normed_motor_scores_chacovol_chronic_ridge_crossval5'

# %%
for atlas in atlases:
        for chaco_type in chaco_types:
            for crossval in crossval_types:
                filename = results_path + '/{}_{}_{}_{}_{}_crossval{}'.format(atlas, y_var, chaco_type, subset, mdl_label,crossval)
              
                if crossval == '2':
                    
                    print('two -  Outer CV: Leave-one-site-out')
                    print(correlation[0].shape)
                    print(scores.shape)
                    np.savetxt(filename + '_scores.txt', scores[0], delimiter = ',')
                    for val in correlation[0]:
                        newfile.append(val[0])
                    np.savetxt(filename + '_correlation.txt', newfile, delimiter = ',')                   
                if crossval == '3':
                    print('three - Outer CV: Group K-fold')
                    np.savetxt(filename + '_scores.txt', scores[0], delimiter = ',')
                    for val in correlation[0]:
                        newfile.append(val[0])
                    np.savetxt(filename + '_correlation.txt', newfile, delimiter = ',')
                    print(tmp[0])
                if crossval == '4':
                    print('four - Shuffle')
                    np.savetxt(filename + '_scores.txt', scores[0], delimiter = ',')
                    for val in correlation[0]:
                        newfile.append(val[0])
                    np.savetxt(filename + '_correlation.txt', newfile, delimiter = ',')
                    print(scores[0])
                if (crossval == '5') | (crossval=='1'):
                    for k in range(0, nperms):
                        print(filename +'_'+ str(k) + '_scores.npy')
                        scores=np.load(filename +'_'+ str(k) + '_scores.npy',allow_pickle=True)
                        correlation = np.load(filename +'_'+ str(k) +'_correlations.npy',allow_pickle=True)
                        print(scores)
                        np.savetxt(filename +'_'+ str(k) +  '_scores.txt', scores[0], delimiter = ',')
                        newfile=[]
                        for val in correlation[0]:
                            newfile.append(val[0])
                        np.savetxt(filename +'_'+ str(k) +  '_correlations.txt', newfile, delimiter = ',')
# Out:
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1_0_scores.npy
# [[0.23466969715986852 0.10677386565851421 0.251152419857682
#   0.2517710524679361 0.08896032071984816]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1_1_scores.npy
# [[0.21627863621977172 0.20804660297058386 0.18957190594630202
#   0.12516444232048107 0.303596303645725]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1_2_scores.npy
# [[0.17712104485586821 0.1564549599113091 0.16063020860196076
#   0.17100444957800365 0.27952906791300425]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1_3_scores.npy
# [[0.2671178332644387 0.19676318367821144 0.16231596148241356
#   0.20876416885132365 0.16475962978609426]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1_4_scores.npy
# [[0.30032614953998116 0.09085522609568641 0.1707679456276039
#   0.21458897121732834 0.21416413915934396]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1_5_scores.npy
# [[0.18400010393541255 0.17114870574915741 0.30566468376246825
#   0.03204922073887928 0.1268276213673596]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1_6_scores.npy
# [[0.25591936843679386 0.15712326785126496 0.19765454332533705
#   0.10309830370530704 0.24747036967691882]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1_7_scores.npy
# [[0.2130557831279043 0.2621751363061613 0.1629303584851871
#   0.09792105467351497 0.3109592057025494]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1_8_scores.npy
# [[0.12638223009666072 0.17429943447217722 0.16854094369837203
#   0.33473194750031 0.03800234960850579]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1_9_scores.npy
# [[0.26017794251586024 0.0943792816923158 0.28613794106311075
#   0.10094760030759553 0.2120779634286063]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1_10_scores.npy
# [[0.1983060221973828 0.23103612024471865 0.15558181805727167
#   0.20696187009221412 0.24440508389910376]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1_11_scores.npy
# [[0.26845827307715875 0.16105282385766695 0.2466975026056859
#   0.06037632075371446 0.24360511106725247]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1_12_scores.npy
# [[0.2161375066241873 0.1116647409389725 0.18249098819307175
#   0.2530368700231953 0.21579553938791063]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1_13_scores.npy
# [[0.17520897765828747 0.2595459197567934 0.2642157427728393
#   0.27542832276648443 0.06409160944550407]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1_14_scores.npy
# [[0.18805796293733335 0.2578485048399086 0.13569962101325028
#   0.1792089114599127 0.1719392368003274]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1_15_scores.npy
# [[0.18817036531455245 0.1471514702422625 0.19223419681126996
#   0.14350951825314262 0.2078698813063835]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1
]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/shen268_normed_motor_scores_chacovol_chronic_ridge_crossval1_17_scores.npy
# [[0.2868662016106749 0.1164292404105105 0.17505656797645086
#   0.09270616633219741 0.06592923101001669]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/shen268_normed_motor_scores_chacovol_chronic_ridge_crossval1_18_scores.npy
# [[0.17702761930661925 0.15778229606646166 0.1971697130937493
#   0.28415948508202293 0.18436090217060008]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/shen268_normed_motor_scores_chacovol_chronic_ridge_crossval1_19_scores.npy
# [[0.2072513584850093 0.20964359332449056 0.16689449278699142
#   0.1864772887364694 0.18979977326854747]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/shen268_normed_motor_scores_chacovol_chronic_ridge_crossval1_20_scores.npy
# [[0.1403707220859911 0.1864824815122863 0.2352790000280529
#   0.14656513251774017 0.14647653910039216]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/shen268_normed_motor_scores_chacovol_chronic_ridge_crossval1_21_scores.npy
# [[0.1676369012218879 0.1378384668386735 0.20504255529510362
#   0.178516550164332 0.31231149217478016]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/shen268_normed_motor_scores_chacovol_chronic_ridge_crossval1_22_scores.npy
# [[0.244038442681474 0.1901776932018836 0.19141930430349197
#   0.21924174130320728 0.20495769521003893]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/shen268_normed_motor_scores_chacovol_chronic_ridge_crossval1_23_scores.npy
# [[0.21190757990573095 0.15987807467669635 0.2859139901872447
#   0.12789136249233513 0.1962366356029701]]
# /Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/shen268_normed_motor_scores_chacovol_chronic_ridge_crossval1_24_scores.npy
# [[0.1631096346909181 0.1531408909066293 0.12232880935643531
#   0.21432186409442067 0.2130696553534157]]

# %%
fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval5_0_scores.npy
# Out:
# '/Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval5_5'

# %%
for atlas in atlases:
    print(atlas)
    for chaco_type in chaco_types:
        for crossval in crossval_types:
            filename = results_path + '/{}_{}_{}_{}_{}_crossval{}'.format(atlas, y_var, chaco_type, subset, mdl_label,crossval)
            newfile=[]
           
            if crossval == '2':
                print('two -  Outer CV: Leave-one-site-out')
                print(correlation[0].shape)
                print(scores.shape)
                np.savetxt(filename + '_scores.txt', scores[0], delimiter = ',')
                for val in correlation[0]:
                    newfile.append(val[0])
                np.savetxt(filename + '_correlation.txt', newfile, delimiter = ',')                   
            if crossval == '3':
                print('three - Outer CV: Group K-fold')
                np.savetxt(filename + '_scores.txt', scores[0], delimiter = ',')
                for val in correlation[0]:
                    newfile.append(val[0])
                np.savetxt(filename + '_correlation.txt', newfile, delimiter = ',')
                print(tmp[0])
            if crossval == '4':
                print('four - Shuffle')
                np.savetxt(filename + '_scores.txt', scores[0], delimiter = ',')
                for val in correlation[0]:
                    newfile.append(val[0])
                np.savetxt(filename + '_correlation.txt', newfile, delimiter = ',')
                print(scores[0])
            if (crossval == '5') | (crossval == '1'):
                for k in range(1, nperms):
                    for j in range(1, nperms):
                        scores=np.load(filename +'_'+ str(j)+'_null_'+ str(k) + '_scores.npy',allow_pickle=True)
                        correlation = np.load(filename +'_'+ str(j)+'_null_'+ str(k) +'_correlations.npy',allow_pickle=True)
                        np.savetxt(filename + '_'+str(j)+'_null_'+ str(k) +  '_scores.txt', scores[0], delimiter = ',')
                        newfile=[]
                        for val in correlation[0]:
                            newfile.append(val[0])
                        np.savetxt(filename +'_'+ str(j)+'_null_'+ str(k) +  '_correlations.txt', newfile, delimiter = ',')
# Out:
# fs86subj
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-120-8342c37717cd> in <module>
#      31                 for k in range(1, nperms):
#      32                     for j in range(1, nperms):
# ---> 33                         scores=np.load(filename +'_'+ str(j)+'_null_'+ str(k) + '_scores.npy',allow_pickle=True)
#      34                         correlation = np.load(filename +'_'+ str(j)+'_null_'+ str(k) +'_correlations.npy',allow_pickle=True)
#      35                         np.savetxt(filename + '_'+str(j)+'_null_'+ str(k) +  '_scores.txt', scores[0], delimiter = ',')
#
# ~/miniforge3/envs/myenv/lib/python3.9/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/emilyolafson/GIT/ENIGMA/enigma_disconnections/results/fs86subj_normed_motor_scores_chacovol_chronic_ridge_crossval1_1_null_1_scores.npy'
